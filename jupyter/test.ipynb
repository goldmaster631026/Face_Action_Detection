# %%
import requests
import json
import base64
import re

username = "Best"
password = "api123"

# Encode the username and password as base64
credentials = f"{username}:{password}".encode('utf-8')
encoded_credentials = base64.b64encode(credentials).decode('utf-8')

# Set the Authorization header with the base64-encoded credentials
headers = {
    "Authorization": f"Basic {encoded_credentials}"
}

# url = "http://172.174.177.117:5000/api/facial_emotion_link"
url = "http://localhost:5000/api/facial_emotion_link"

data = {
    # "videoLink": "https://fiverr-res.cloudinary.com/images/t_main1,q_auto,f_auto,q_auto,f_auto/gigs/157114860/original/49940e4fed3a055026628da18c5d41a9a194a7b0/do-job-mock-interview-coaching.jpg"
    # "videoLink": "https://drive.google.com/file/d/13gzUPnec7as9dBmkM_M0vh4DvQSN5TWH/view?usp=drive_link"
    # "videoLink" : "https://idinnovsas-my.sharepoint.com/:f:/g/personal/gsanchez_idinnov_com/EiPrRM_UNFdHqc9K2aOV2uYBRrb9dqX8TILvxer4--tz4g?e=hFQ0d6"
    # "videoLink" : "https://onedrive.live.com/?authkey=%21AFgC2bjCOo6YgxI&id=4D72AE9C06C25662%219874&cid=4D72AE9C06C25662"
    
    
    # "videoLink": "https://idinnovsas-my.sharepoint.com/:v:/g/personal/gsanchez_idinnov_com/Ec5yNo5QfZlDuRSstMuYGUIBaiYpXhIxaq4Tdi54MzTI-A?nav=eyJyZWZlcnJhbEluZm8iOnsicmVmZXJyYWxBcHAiOiJPbmVEcml2ZUZvckJ1c2luZXNzIiwicmVmZXJyYWxBcHBQbGF0Zm9ybSI6IldlYiIsInJlZmVycmFsTW9kZSI6InZpZXciLCJyZWZlcnJhbFZpZXciOiJNeUZpbGVzTGlua0NvcHkifX0&e=hNqmUL"
    # "videoLink": "https://idinnovsas-my.sharepoint.com/:v:/g/personal/gsanchez_idinnov_com/Efene7A9k-NOlmFjx4lXEBEB3x1VTa72-niJ3LUlTH0DsA?nav=eyJyZWZlcnJhbEluZm8iOnsicmVmZXJyYWxBcHAiOiJPbmVEcml2ZUZvckJ1c2luZXNzIiwicmVmZXJyYWxBcHBQbGF0Zm9ybSI6IldlYiIsInJlZmVycmFsTW9kZSI6InZpZXciLCJyZWZlcnJhbFZpZXciOiJNeUZpbGVzTGlua0NvcHkifX0&e=kFhF23"
    # "videoLink": "https://drive.google.com/drive/folders/142JGC0mTdYoRNhnHU-2xU9WwxUj5Xfv-?usp=sharing"
    
    # "videoLink": "https://1drv.ms/f/s!AmJWwgacrnJNzQwBZgq9n6tA28X3?e=UbzLf6"
    # "videoLink": "https://1drv.ms/v/s!AmJWwgacrnJNzQ-XuMpY_5P7R1LW?e=BtbcVs"
    # "videoLink": "https://idinnovsas-my.sharepoint.com/:f:/g/personal/gsanchez_idinnov_com/Eij6Ix-ALxZJgbLCAY0rXOUBqxg9AlvSiZd83KaNJ1lHCg?e=Sglpd6"
    # "videoLink" : "https://1drv.ms/f/s!AmJWwgacrnJNzRJYAtm4wjqOmIMS?e=KGH5yq"
    "videoLink" : "https://drive.google.com/drive/folders/142JGC0mTdYoRNhnHU-2xU9WwxUj5Xfv-?usp=sharing"
    
}

response = requests.post(url, json = data,  headers = headers)
# print("Request successful")
# print(response.text)
# Check the response status code
if response.status_code == 200:
    print("Request successful")
    print(response.text)
    with open("M.txt", "w") as file:
        file.write(response.text)
else:
    print("Request failed with status code", response.status_code)
# Out:
# Request successful
# Video 4.mp4
# {
#     "Frame_0.0": {
#         "person 0": {
#             "Face Location": {
#                 "top_left": [
#                     341,
#                     38
#                 ],
#                 "bottom_right": [
#                     431,
#                     181
#                 ]
#             },
#             "Face expression": "neutral",
#             "Right Eye Location": {
#                 "x": 352,
#                 "y": 91
#             },
#             "Left Eye Location": {
#                 "x": 379,
#                 "y": 91
#             },
#             "Noise Eye Location": {
#                 "x": 349,
#                 "y": 119
#             },
#             "Right Mouse Location": {
#                 "x": 359,
#                 "y": 144
#             },
#             "Left Mouse Location": {
#                 "x": 385,
#                 "y": 143
#             }
#         },
#         "person 1": {
# ...

# %%
# import requests
# import json
# import base64

# url_file = "http://172.174.177.117:5000/api/facial_emotion_video"

# username = "Best"
# password = "api123"

# # Encode the username and password as base64
# credentials = f"{username}:{password}".encode('utf-8')
# encoded_credentials = base64.b64encode(credentials).decode('utf-8')

# # Set the Authorization header with the base64-encoded credentials
# headers = {
#     "Authorization": f"Basic {encoded_credentials}"
# }

# # Assuming you have the video file stored in a variable called 'video_file'
# with open('1.jpg', 'rb') as file:
#     files = {'video': (file.name, file, 'multipart/form-data')}
#     response = requests.post(url_file, files=files,  headers=headers)

# data = response.text
# print(data)

# # if response.status_code == 200:
# #     try:
# #         data = response.json()
# #         print(data)
# #     except ValueError:
# #         print("Invalid JSON response:", response.text)
# # else:
# #     print("Request failed with status code:", response.status_code)
# Out:
# {
#     "Frame_0.0/s": {
#         "person 0": {
#             "Face Location": {
#                 "top_left": [
#                     225,
#                     -54
#                 ],
#                 "bottom_right": [
#                     642,
#                     452
#                 ]
#             },
#             "Face expression": "sad",
#             "Right Eye Location": {
#                 "x": 365,
#                 "y": 173
#             },
#             "Left Eye Location": {
#                 "x": 564,
#                 "y": 166
#             },
#             "Noise Eye Location": {
#                 "x": 490,
#                 "y": 296
#             },
#             "Right Mouse Location": {
#                 "x": 384,
#                 "y": 379
#             },
#             "Left Mouse Location": {
#                 "x": 553,
#                 "y": 374
#             }
#         },
#         "Caption of Frame": " "
#     }
# }
# SFEFEEF
